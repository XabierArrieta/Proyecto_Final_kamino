# %% [markdown]
# # Test Colecciones

# %%
import sys
sys.path.append("../")

import pandas as pd
from src.funciones_queries import *

# %%
list(db.list_collections())
# Out:
# [{'name': 'Restauracion',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': UUID('3ebc0102-49d9-4a0d-a5f5-e51c17166493')},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'Patrimonio',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': UUID('ba0764b0-8b6b-4a1c-a0d9-d4dd3614281c')},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'Alojamiento',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': UUID('f889ab8a-d498-4112-8ddd-937be5cfd547')},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}}]

# %% [markdown]
# ## Test Alojamiento

# %%
#Todos los alojaminetos por localidad
q1 = {"LOCALIDAD":"PAMPLONA"}

z1 = list(db.Alojamiento.find(q1,{"_id":0, "CÓDIGO":0}))

z1[:5]
# Out:
# [{'NOMBRE': '22 Caldereros',
#   'MODALIDAD': 'Apartamento Turístico',
#   'CATEGORIA': 'Segunda/2 Llaves',
#   'DIRECCIÓN': 'Calle Caldereria 22 2º',
#   'LOCALIDAD': 'PAMPLONA',
#   'ZONA': 'Cuenca de Pamplona',
#   'PLAZAS': '3.0',
#   'COORDENADAS': '(42.81825260000001, -1.6420324)'},
#  {'NOMBRE': 'A Pamplona',
#   'MODALIDAD': 'Hotel',
#   'CATEGORIA': '2 Estrellas',
#   'DIRECCIÓN': 'Calle Sancho Ramirez 15',
#   'LOCALIDAD': 'PAMPLONA',
#   'ZONA': 'Cuenca de Pamplona',
#   'PLAZAS': '24.0',
#   'COORDENADAS': '(42.8072773, -1.6649481)'},
#  {'NOMBRE': 'Abba Reino de Navarra',
#   'MODALIDAD': 'Hotel',
#   'CATEGORIA': '4 Estrellas',
#   'DIRECCIÓN': 'Calle Acella 1',
#   'LOCALIDAD': 'PAMPLONA',
#   'ZONA': 'Cuenca de Pamplona',
#   'PLAZAS': '176.0',
#   'COORDENADAS': '(42.8085463, -1.6607907)'},
#  {'NOMBRE': 'Abodi II',
#   'MODALIDAD': 'Hostal',
#   'CATEGORIA': 'HsG',
#   'DIRECCIÓN': 'Calle Sancho Ramírez 31',
#   'LOCALIDAD': 'PAMPLONA',
#   'ZONA': 'Cuenca de Pamplona',
#   'PLAZAS': '8.0',
#   'COORDENADAS': '(42.8082357, -1.6662554)'},
#  {'NOMBRE': 'AC Ciudad de Pamplona',
#   'MODALIDAD': 'Hotel',
#   'CATEGORIA': '4 Estrellas',
#   'DIRECCIÓN': 'Iturrama 21',
#   'LOCALIDAD': 'PAMPLONA',
#   'ZONA': 'Cuenca de Pamplona',
#   'PLAZAS': '178.0',
#   'COORDENADAS': '(42.8045626, -1.6524894)'}]

# %%
# Todos los alojamiento de una localidad y mostrando que tipo de alojamiento
q2 = {"LOCALIDAD":"PAMPLONA"}

z2 = list(db.Alojamiento.find(q2,{"_id":0, "MODALIDAD":1, "NOMBRE":1}))

z2[:10]
# Out:
# [{'NOMBRE': '22 Caldereros', 'MODALIDAD': 'Apartamento Turístico'},
#  {'NOMBRE': 'A Pamplona', 'MODALIDAD': 'Hotel'},
#  {'NOMBRE': 'Abba Reino de Navarra', 'MODALIDAD': 'Hotel'},
#  {'NOMBRE': 'Abodi II', 'MODALIDAD': 'Hostal'},
#  {'NOMBRE': 'AC Ciudad de Pamplona', 'MODALIDAD': 'Hotel'},
#  {'NOMBRE': 'Acella 4', 'MODALIDAD': 'Hostal'},
#  {'NOMBRE': 'Acella II', 'MODALIDAD': 'Pensión'},
#  {'NOMBRE': 'Albergue Plaza Catedral', 'MODALIDAD': 'Albergue turístico'},
#  {'NOMBRE': 'Albret', 'MODALIDAD': 'Hotel'},
#  {'NOMBRE': 'Alisol', 'MODALIDAD': 'Apartamento Turístico'}]

# %%
# Todos los alojamiento de una localidad por modalidad y mostrando su nombre
q3 = {"$and":[{"LOCALIDAD":"PAMPLONA"},{"MODALIDAD":"Hotel"}]}

z3 = list(db.Alojamiento.find(q3,{"_id":0, "MODALIDAD":1, "NOMBRE":1, "LOCALIDAD":1}))

z3[:5]
# Out:
# [{'NOMBRE': 'A Pamplona', 'MODALIDAD': 'Hotel', 'LOCALIDAD': 'PAMPLONA'},
#  {'NOMBRE': 'Abba Reino de Navarra',
#   'MODALIDAD': 'Hotel',
#   'LOCALIDAD': 'PAMPLONA'},
#  {'NOMBRE': 'AC Ciudad de Pamplona',
#   'MODALIDAD': 'Hotel',
#   'LOCALIDAD': 'PAMPLONA'},
#  {'NOMBRE': 'Albret', 'MODALIDAD': 'Hotel', 'LOCALIDAD': 'PAMPLONA'},
#  {'NOMBRE': 'Alma Pamplona', 'MODALIDAD': 'Hotel', 'LOCALIDAD': 'PAMPLONA'}]

# %%
# Todos los alojamiento de una localidad por modalidad, mostrando su nombre Y dirección
q4 = {"$and":[{"LOCALIDAD":"PAMPLONA"},{"MODALIDAD":"Hotel"}]}

z4 = list(db.Alojamiento.find(q4,{"_id":0, "MODALIDAD":1, "NOMBRE":1, "LOCALIDAD":1, "DIRECCIÓN":1}))

z4[:5]
# Out:
# [{'NOMBRE': 'A Pamplona',
#   'MODALIDAD': 'Hotel',
#   'DIRECCIÓN': 'Calle Sancho Ramirez 15',
#   'LOCALIDAD': 'PAMPLONA'},
#  {'NOMBRE': 'Abba Reino de Navarra',
#   'MODALIDAD': 'Hotel',
#   'DIRECCIÓN': 'Calle Acella 1',
#   'LOCALIDAD': 'PAMPLONA'},
#  {'NOMBRE': 'AC Ciudad de Pamplona',
#   'MODALIDAD': 'Hotel',
#   'DIRECCIÓN': 'Iturrama 21',
#   'LOCALIDAD': 'PAMPLONA'},
#  {'NOMBRE': 'Albret',
#   'MODALIDAD': 'Hotel',
#   'DIRECCIÓN': 'Ermitagaña 3',
#   'LOCALIDAD': 'PAMPLONA'},
#  {'NOMBRE': 'Alma Pamplona',
#   'MODALIDAD': 'Hotel',
#   'DIRECCIÓN': 'Calle Beloso Bajo 11',
#   'LOCALIDAD': 'PAMPLONA'}]

# %% [markdown]
# ## Test Restauración

# %%
#Todas las opciones de Restauración por localidad
q1 = {"LOCALIDAD":"ESTELLA"}

z1 = list(db.Restauracion.find(q1,{"_id":0, "CÓDIGO":0}))

z1[:5]
# Out:
# [{'NOMBRE': 'Asador La Tasca',
#   'MODALIDAD': 'Restaurantes',
#   'CATEGORÍA': 'Sin definir',
#   'DIRECCIÓN': 'Navarro Villoslada 1',
#   'LOCALIDAD': 'ESTELLA',
#   'ZONA': 'Zona Media',
#   'ESPECIALIDAD': 'Asador',
#   'COORDENADAS': '(42.8126733, -1.6394528)'},
#  {'NOMBRE': 'Astarriaga',
#   'MODALIDAD': 'Restaurantes',
#   'CATEGORÍA': 'Primera/3 tenedores',
#   'DIRECCIÓN': 'de los Fueros 12',
#   'LOCALIDAD': 'ESTELLA',
#   'ZONA': 'Zona Media',
#   'ESPECIALIDAD': 'Asador',
#   'COORDENADAS': '(42.8438787, -2.6699281)'},
#  {'NOMBRE': 'Casa de Comidas San Miguel',
#   'MODALIDAD': 'Restaurantes',
#   'CATEGORÍA': 'Sin definir',
#   'DIRECCIÓN': 'Calle Espoz y Mina 7',
#   'LOCALIDAD': 'ESTELLA',
#   'ZONA': 'Zona Media',
#   'ESPECIALIDAD': 'Casera o regional',
#   'COORDENADAS': '(40.4157547, -3.702127199999999)'},
#  {'NOMBRE': 'Casanova',
#   'MODALIDAD': 'Restaurantes',
#   'CATEGORÍA': 'Segunda/2 Tenedores',
#   'DIRECCIÓN': 'Fray Wenceslao de Oñate 8',
#   'LOCALIDAD': 'ESTELLA',
#   'ZONA': 'Zona Media',
#   'ESPECIALIDAD': 'Casera o regional',
#   'COORDENADAS': '(42.67215909999999, -2.0324258)'},
#  {'NOMBRE': 'China Town',
#   'MODALIDAD': 'Restaurantes',
#   'CATEGORÍA': 'Tercera/1 tenedor',
#   'DIRECCIÓN': 'Paseo de la Inmaculada 72',
#   'LOCALIDAD': 'ESTELLA',
#   'ZONA': 'Zona Media',
#   'ESPECIALIDAD': 'Internacional',
#   'COORDENADAS': '(42.6721555, -2.0342455)'}]

# %%
# Toda la restauración de una localidad y mostrando qué tipo y su nombre
q2 = {"LOCALIDAD":"ESTELLA"}

z2 = list(db.Restauracion.find(q2,{"_id":0, "MODALIDAD":1, "NOMBRE":1}))

z2[:10]
# Out:
# [{'NOMBRE': 'Asador La Tasca', 'MODALIDAD': 'Restaurantes'},
#  {'NOMBRE': 'Astarriaga', 'MODALIDAD': 'Restaurantes'},
#  {'NOMBRE': 'Casa de Comidas San Miguel', 'MODALIDAD': 'Restaurantes'},
#  {'NOMBRE': 'Casanova', 'MODALIDAD': 'Restaurantes'},
#  {'NOMBRE': 'China Town', 'MODALIDAD': 'Restaurantes'},
#  {'NOMBRE': 'Don Menú', 'MODALIDAD': 'Restaurantes'},
#  {'NOMBRE': 'El Volante', 'MODALIDAD': 'Restaurantes'},
#  {'NOMBRE': 'Florida', 'MODALIDAD': 'Restaurantes'},
#  {'NOMBRE': 'La Aljama', 'MODALIDAD': 'Restaurantes'},
#  {'NOMBRE': 'La Cepa', 'MODALIDAD': 'Restaurantes'}]

# %%
# Todos los restaurantes de una localidad por modalidad y mostrando su nombre y localidad
q3 = {"$and":[{"LOCALIDAD":"ESTELLA"},{"MODALIDAD":"Restaurantes"}]}

z3 = list(db.Restauracion.find(q3,{"_id":0, "MODALIDAD":1, "NOMBRE":1, "LOCALIDAD":1}))

z3[:5]
# Out:
# [{'NOMBRE': 'Asador La Tasca',
#   'MODALIDAD': 'Restaurantes',
#   'LOCALIDAD': 'ESTELLA'},
#  {'NOMBRE': 'Astarriaga', 'MODALIDAD': 'Restaurantes', 'LOCALIDAD': 'ESTELLA'},
#  {'NOMBRE': 'Casa de Comidas San Miguel',
#   'MODALIDAD': 'Restaurantes',
#   'LOCALIDAD': 'ESTELLA'},
#  {'NOMBRE': 'Casanova', 'MODALIDAD': 'Restaurantes', 'LOCALIDAD': 'ESTELLA'},
#  {'NOMBRE': 'China Town', 'MODALIDAD': 'Restaurantes', 'LOCALIDAD': 'ESTELLA'}]

# %%
# Todos los Restaurantes de una localidad por modalidad, mostrando su nombre, dirección y localidad
q4 = {"$and":[{"LOCALIDAD":"ESTELLA"},{"MODALIDAD":"Restaurantes"}]}

z4 = list(db.Restauracion.find(q4,{"_id":0, "MODALIDAD":1, "NOMBRE":1, "LOCALIDAD":1, "DIRECCIÓN":1}))

z4[:5]
# Out:
# [{'NOMBRE': 'Asador La Tasca',
#   'MODALIDAD': 'Restaurantes',
#   'DIRECCIÓN': 'Navarro Villoslada 1',
#   'LOCALIDAD': 'ESTELLA'},
#  {'NOMBRE': 'Astarriaga',
#   'MODALIDAD': 'Restaurantes',
#   'DIRECCIÓN': 'de los Fueros 12',
#   'LOCALIDAD': 'ESTELLA'},
#  {'NOMBRE': 'Casa de Comidas San Miguel',
#   'MODALIDAD': 'Restaurantes',
#   'DIRECCIÓN': 'Calle Espoz y Mina 7',
#   'LOCALIDAD': 'ESTELLA'},
#  {'NOMBRE': 'Casanova',
#   'MODALIDAD': 'Restaurantes',
#   'DIRECCIÓN': 'Fray Wenceslao de Oñate 8',
#   'LOCALIDAD': 'ESTELLA'},
#  {'NOMBRE': 'China Town',
#   'MODALIDAD': 'Restaurantes',
#   'DIRECCIÓN': 'Paseo de la Inmaculada 72',
#   'LOCALIDAD': 'ESTELLA'}]

# %% [markdown]
# ## Test Patrimonio

# %%
#Todas las opciones de Patrimonio por localidad
q1 = {"LOCALIDAD":"PUENTE LA REINA"}

z1 = list(db.Patrimonio.find(q1,{"_id":0, "CÓDIGO":0}))

z1[:5]
# Out:
# [{'NOMBRE': 'Casa del Vínculo',
#   'CATEGORÍA': 'Edificios públicos de interés',
#   'ESTILO': 'no definido',
#   'LOCALIDAD': 'PUENTE LA REINA',
#   'ZONA': 'Zona Media',
#   'COORDENADAS': '(10.5053836, -66.91408009999999)'},
#  {'NOMBRE': 'Iglesia de Santiago el Mayor',
#   'CATEGORÍA': 'Iglesias y ermitas',
#   'ESTILO': 'Románico',
#   'LOCALIDAD': 'PUENTE LA REINA',
#   'ZONA': 'Zona Media',
#   'COORDENADAS': '(41.6526763, -0.8853006)'},
#  {'NOMBRE': 'Iglesia del Crucifijo',
#   'CATEGORÍA': 'Iglesias y ermitas',
#   'ESTILO': 'Gótico, Románico',
#   'LOCALIDAD': 'PUENTE LA REINA',
#   'ZONA': 'Zona Media',
#   'COORDENADAS': '(42.6731287, -1.8107319)'},
#  {'NOMBRE': 'Puente Románico de Puente la Reina',
#   'CATEGORÍA': 'Obras de ingeniería',
#   'ESTILO': 'Románico',
#   'LOCALIDAD': 'PUENTE LA REINA',
#   'ZONA': 'Zona Media',
#   'COORDENADAS': '(42.6711661, -1.8188069)'}]

# %%
# Todo el patrimonio de una localidad y 
q2 = {"LOCALIDAD":"PUENTE LA REINA"}

z2 = list(db.Patrimonio.find(q2,{"_id":0, "CATEGORÍA":1, "NOMBRE":1}))

z2[:10]
# Out:
# [{'NOMBRE': 'Casa del Vínculo', 'CATEGORÍA': 'Edificios públicos de interés'},
#  {'NOMBRE': 'Iglesia de Santiago el Mayor', 'CATEGORÍA': 'Iglesias y ermitas'},
#  {'NOMBRE': 'Iglesia del Crucifijo', 'CATEGORÍA': 'Iglesias y ermitas'},
#  {'NOMBRE': 'Puente Románico de Puente la Reina',
#   'CATEGORÍA': 'Obras de ingeniería'}]

# %%
# Todos el patrimonio de una localidad y mostrando nombre, categoría y estilo
q3 = {"LOCALIDAD":"PUENTE LA REINA"}

z3 = list(db.Patrimonio.find(q3,{"_id":0,"CATEGORÍA":1, "NOMBRE":1, "ESTILO":1}))

z3[:5]
# Out:
# [{'NOMBRE': 'Casa del Vínculo',
#   'CATEGORÍA': 'Edificios públicos de interés',
#   'ESTILO': 'no definido'},
#  {'NOMBRE': 'Iglesia de Santiago el Mayor',
#   'CATEGORÍA': 'Iglesias y ermitas',
#   'ESTILO': 'Románico'},
#  {'NOMBRE': 'Iglesia del Crucifijo',
#   'CATEGORÍA': 'Iglesias y ermitas',
#   'ESTILO': 'Gótico, Románico'},
#  {'NOMBRE': 'Puente Románico de Puente la Reina',
#   'CATEGORÍA': 'Obras de ingeniería',
#   'ESTILO': 'Románico'}]

# %%
# Todo el patrimonio de una localidad mostrando sus coordenadas
q4 = {"LOCALIDAD":"PUENTE LA REINA"}

z4 = list(db.Patrimonio.find(q4,{"_id":0, "NOMBRE":1, "LOCALIDAD":1, "COORDENADAS":1}))

z4[:5]
# Out:
# [{'NOMBRE': 'Casa del Vínculo',
#   'LOCALIDAD': 'PUENTE LA REINA',
#   'COORDENADAS': '(10.5053836, -66.91408009999999)'},
#  {'NOMBRE': 'Iglesia de Santiago el Mayor',
#   'LOCALIDAD': 'PUENTE LA REINA',
#   'COORDENADAS': '(41.6526763, -0.8853006)'},
#  {'NOMBRE': 'Iglesia del Crucifijo',
#   'LOCALIDAD': 'PUENTE LA REINA',
#   'COORDENADAS': '(42.6731287, -1.8107319)'},
#  {'NOMBRE': 'Puente Románico de Puente la Reina',
#   'LOCALIDAD': 'PUENTE LA REINA',
#   'COORDENADAS': '(42.6711661, -1.8188069)'}]

# %% [markdown]
# # Funciones y mapas

# %%
localidad()
# Out:
# Localidad: Pamplona
# ('PAMPLONA', [42.8184538, -1.6442556])

# %%
localidad()
# Out:
# Localidad: Estella
# ('ESTELLA', [42.672094, -2.0314834])

# %%
localidad()
# Out:
# Localidad: Puente la reina
# ('PUENTE LA REINA', [42.6717107, -1.8155291])

# %%
locali_colec_coord("Patrimonio", "ESTELLA")
# Out:
# [{'COORDENADAS': '(42.66888549999999, -2.0293285)'},
#  {'COORDENADAS': '(42.67517530000001, -2.0301336)'},
#  {'COORDENADAS': '(32.68603179999999, -97.27110719999999)'},
#  {'COORDENADAS': '(42.66888549999999, -2.0293285)'},
#  {'COORDENADAS': '(31.7784813, 35.2296002)'},
#  {'COORDENADAS': '(42.66863170000001, -2.0267893)'},
#  {'COORDENADAS': '(42.6693199, -2.0295577)'}]

# %%
locali_colec_coord("Alojamiento", "PAMPLONA")[:5]
# Out:
# [{'COORDENADAS': '(42.81825260000001, -1.6420324)'},
#  {'COORDENADAS': '(42.8072773, -1.6649481)'},
#  {'COORDENADAS': '(42.8085463, -1.6607907)'},
#  {'COORDENADAS': '(42.8082357, -1.6662554)'},
#  {'COORDENADAS': '(42.8045626, -1.6524894)'}]

# %%
locali_colec_coord("Alojamiento", "ESTELLA")[:5]
# Out:
# [{'COORDENADAS': '(42.6724857, -2.030961)'},
#  {'COORDENADAS': '(42.659645, -2.0299289)'},
#  {'COORDENADAS': '(42.5894973, -2.092264)'},
#  {'COORDENADAS': '(42.7599623, -1.9196949)'},
#  {'COORDENADAS': '(40.40602490000001, -3.8999126)'}]

# %%
locali_colec_coord("Restauracion", "PUENTE LA REINA")[:10]
# Out:
# [{'COORDENADAS': '(40.3703304, -3.6907401)'},
#  {'COORDENADAS': '(43.3381465, -1.7888495)'},
#  {'COORDENADAS': '(42.8438787, -2.6699281)'},
#  {'COORDENADAS': '(33.8080401, -118.3893071)'},
#  {'COORDENADAS': '(33.8080372, -118.389302)'},
#  {'COORDENADAS': '(35.2894921, -95.5822563)'}]

# %%
mapa("Alojamiento")
# Out:
# Localidad: PAMPLONA
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_759a2f7aea534815837f5c036b20c2e6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_759a2f7aea534815837f5c036b20c2e6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_759a2f7aea534815837f5c036b20c2e6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_759a2f7aea534815837f5c036b20c2e6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.8184538%2C%20-1.6442556%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
mapa("Alojamiento")
# Out:
# Localidad: Estella
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6e7bf3e38dc6403ab679bf3755bb7466%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6e7bf3e38dc6403ab679bf3755bb7466%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6e7bf3e38dc6403ab679bf3755bb7466%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6e7bf3e38dc6403ab679bf3755bb7466%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.672094%2C%20-2.0314834%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
mapa("Patrimonio")
# Out:
# Localidad: PUENTE LA REINA
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7bcd7b8529df40e89198d1b2e796f120%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7bcd7b8529df40e89198d1b2e796f120%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7bcd7b8529df40e89198d1b2e796f120%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7bcd7b8529df40e89198d1b2e796f120%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.6717107%2C%20-1.8155291%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
mapa("Restauracion")
# Out:
# Localidad: Estella
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_27a99f3a03c440479404bd57594c225b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_27a99f3a03c440479404bd57594c225b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_27a99f3a03c440479404bd57594c225b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_27a99f3a03c440479404bd57594c225b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.672094%2C%20-2.0314834%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
mapa("Restauracion")
# Out:
# Localidad: Estella
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f5419dd2b1374580917e70f40e74f15a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f5419dd2b1374580917e70f40e74f15a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f5419dd2b1374580917e70f40e74f15a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f5419dd2b1374580917e70f40e74f15a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.672094%2C%20-2.0314834%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# Pruebas

# %%
def locali_colec_coord(coleccion, *lugar):
    
    """
    La función recibe una colección y un lugar; hace una query a la colección seleccionada y el lugar
    especifivado y devuelve las coordenadas de los lugares encontrados.
   
    
    Input: Nombre de la colección y localidad
    Output: Las coordenadas de la localidad
    
    """
    bbdd = db[f'{coleccion}']
    query = {"LOCALIDAD":f"{lugar[0]}"}
    coordenadas = bbdd.find(query,{"_id":0,"COORDENADAS":1,"NOMBRE":1})
    df = pd.DataFrame(coordenadas)
    return df

# %%
df = locali_colec_coord("Patrimonio", "PAMPLONA")[6:15]
df
# Out:
#                         NOMBRE               COORDENADAS
# 6     Iglesia de San Saturnino  (42.8182133, -1.6449881)
# 7        Monumento al Encierro   (42.814787, -1.6413238)
# 8         Murallas de Pamplona  (42.8124662, -1.6494942)
# 9           Palacio de Navarra  (42.8159536, -1.6425586)
# 10     Palacio del Condestable  (42.8182832, -1.6454901)
# 11  Plaza de Toros de Pamplona  (42.8156478, -1.6399125)

# %%
for x, y in df.iterrows():
    #print(x)
    print(y)
# Out:
# NOMBRE         Iglesia de San Saturnino
# COORDENADAS    (42.8182133, -1.6449881)
# Name: 6, dtype: object
# NOMBRE           Monumento al Encierro
# COORDENADAS    (42.814787, -1.6413238)
# Name: 7, dtype: object
# NOMBRE             Murallas de Pamplona
# COORDENADAS    (42.8124662, -1.6494942)
# Name: 8, dtype: object
# NOMBRE               Palacio de Navarra
# COORDENADAS    (42.8159536, -1.6425586)
# Name: 9, dtype: object
# NOMBRE          Palacio del Condestable
# COORDENADAS    (42.8182832, -1.6454901)
# Name: 10, dtype: object
# NOMBRE         Plaza de Toros de Pamplona
# COORDENADAS      (42.8156478, -1.6399125)
# Name: 11, dtype: object

# %%
lat = df.iloc[0]['COORDENADAS'].split(",")[0][1:]
lon = df.iloc[0]['COORDENADAS'].split(",")[1][:-1]
nombre = df.iloc[0]['NOMBRE']

# %%
lat
# Out:
# '42.8182133'

# %%
lon
# Out:
# ' -1.6449881'

# %%
nombre
# Out:
# 'Iglesia de San Saturnino'

# %%
df
# Out:
#                         NOMBRE               COORDENADAS
# 6     Iglesia de San Saturnino  (42.8182133, -1.6449881)
# 7        Monumento al Encierro   (42.814787, -1.6413238)
# 8         Murallas de Pamplona  (42.8124662, -1.6494942)
# 9           Palacio de Navarra  (42.8159536, -1.6425586)
# 10     Palacio del Condestable  (42.8182832, -1.6454901)
# 11  Plaza de Toros de Pamplona  (42.8156478, -1.6399125)

# %%
for x, y in df.iterrows():
    lati=[]
    long=[]
    nomb=[]
    
    lat = df.iloc[0]['COORDENADAS'].split(",")[0][1:]
    lon = df.iloc[0]['COORDENADAS'].split(",")[1][:-1]
    nombre = df.iloc[0]['NOMBRE']
    
    lati.append(lat)
    long.append(lon)
    nomb.append(nombre)
    
    print(lati, long, nomb)
# Out:
# ['42.8182133'] [' -1.6449881'] ['Iglesia de San Saturnino']
# ['42.8182133'] [' -1.6449881'] ['Iglesia de San Saturnino']
# ['42.8182133'] [' -1.6449881'] ['Iglesia de San Saturnino']
# ['42.8182133'] [' -1.6449881'] ['Iglesia de San Saturnino']
# ['42.8182133'] [' -1.6449881'] ['Iglesia de San Saturnino']
# ['42.8182133'] [' -1.6449881'] ['Iglesia de San Saturnino']

# %%
for x, y in df.iterrows():
    print(y["NOMBRE"], y["COORDENADAS"])
# Out:
# Iglesia de San Saturnino (42.8182133, -1.6449881)
# Monumento al Encierro (42.814787, -1.6413238)
# Murallas de Pamplona (42.8124662, -1.6494942)
# Palacio de Navarra (42.8159536, -1.6425586)
# Palacio del Condestable (42.8182832, -1.6454901)
# Plaza de Toros de Pamplona (42.8156478, -1.6399125)

# %%
for x, y in df.iterrows():
    lati=[]
    long=[]
    nomb=[]
    
    lat = y['COORDENADAS'].split(",")[0][1:]
    lon = y['COORDENADAS'].split(",")[1][:-1]
    nombre = y['NOMBRE']
    
    lati.append(lat)
    long.append(lon)
    nomb.append(nombre)
    
    print(lati, long, nomb)
# Out:
# ['42.8182133'] [' -1.6449881'] ['Iglesia de San Saturnino']
# ['42.814787'] [' -1.6413238'] ['Monumento al Encierro']
# ['42.8124662'] [' -1.6494942'] ['Murallas de Pamplona']
# ['42.8159536'] [' -1.6425586'] ['Palacio de Navarra']
# ['42.8182832'] [' -1.6454901'] ['Palacio del Condestable']
# ['42.8156478'] [' -1.6399125'] ['Plaza de Toros de Pamplona']

# %%
for x, y in df.iterrows():
   
    
    lat = y['COORDENADAS'].split(",")[0][1:]
    lon = y['COORDENADAS'].split(",")[1][:-1]
    nombre = y['NOMBRE']

    print(lat, lon, nombre)
# Out:
# 42.8182133  -1.6449881 Iglesia de San Saturnino
# 42.814787  -1.6413238 Monumento al Encierro
# 42.8124662  -1.6494942 Murallas de Pamplona
# 42.8159536  -1.6425586 Palacio de Navarra
# 42.8182832  -1.6454901 Palacio del Condestable
# 42.8156478  -1.6399125 Plaza de Toros de Pamplona

# %%
lat = df.iloc[0]['COORDENADAS'].split(",")[0][1:]
lon = df.iloc[0]['COORDENADAS'].split(",")[1][:-1]
nombre = df.iloc[0]['NOMBRE']
print(nombre)
# Out:
# Iglesia de San Saturnino

# %%
lat = df.iloc[0]['COORDENADAS'].split(",")[0][1:]
lon = df.iloc[0]['COORDENADAS'].split(",")[1][:-1]
nombre = df.iloc[0]['NOMBRE']
print(lat)
# Out:
# 42.8182133
